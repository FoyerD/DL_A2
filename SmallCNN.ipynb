# %%
import pandas as pd
import torch.nn as nn
from sklearn.model_selection import train_test_split
from PIL import Image
import torch
from torchvision import transforms
import os
from more_itertools import peekable
import torch.optim.lr_scheduler as lr_scheduler
import matplotlib.pyplot as plt
from torch.cuda import is_available as is_cuda_available
import torch.nn.init as init
import random
from itertools import combinations, product
from torch.utils.data import Dataset, DataLoader
import math
import torch.onnx
cwd = os.getcwd()
print(is_cuda_available())
print("Current working directory:", cwd)
# Out:
# True
# Current working directory: /sise/home/amitfoye/code_files/DL_A2

# %% [markdown]
# # The Data

# %%
dataset_path = os.path.join(cwd, "lfw")
images_path = os.path.join(dataset_path, "lfw-deepfunneled", "lfw-deepfunneled")

# %% [markdown]
# ## Loading The Given Pairs

# %% [markdown]
# ### Load The Data

# %%
match_dev_test_df = pd.read_csv(os.path.join(dataset_path, "matchpairsDevTest.csv")).sort_index()
match_dev_train_df = pd.read_csv(os.path.join(dataset_path, "matchpairsDevTrain.csv")).sort_index()
mismatch_dev_test_df = pd.read_csv(os.path.join(dataset_path, "mismatchpairsDevTest.csv")).sort_index()
mismatch_dev_train_df = pd.read_csv(os.path.join(dataset_path, "mismatchpairsDevTrain.csv")).sort_index()

match_dev_train_df, match_dev_val_df = train_test_split(
    match_dev_train_df, test_size=0.2, random_state=42
)
mismatch_dev_train_df, mismatch_dev_val_df = train_test_split(
    mismatch_dev_train_df, test_size=0.2, random_state=42
)

match_dev_train_df = match_dev_train_df.reset_index(drop=True)
match_dev_val_df = match_dev_val_df.reset_index(drop=True)
mismatch_dev_train_df = mismatch_dev_train_df.reset_index(drop=True)
mismatch_dev_val_df = mismatch_dev_val_df.reset_index(drop=True)

# %% [markdown]
# ### Preprocessing

# %%
match_dev_train_df['name1'] = match_dev_train_df['name']
match_dev_train_df['name2'] = match_dev_train_df['name']
match_dev_train_df = match_dev_train_df[['name1', 'imagenum1', 'name2', 'imagenum2']]
match_dev_train_df['label'] = 1

match_dev_val_df['name1'] = match_dev_val_df['name']
match_dev_val_df['name2'] = match_dev_val_df['name']
match_dev_val_df = match_dev_val_df[['name1', 'imagenum1', 'name2', 'imagenum2']]
match_dev_val_df['label'] = 1

match_dev_test_df['name1'] = match_dev_test_df['name']
match_dev_test_df['name2'] = match_dev_test_df['name']
match_dev_test_df = match_dev_test_df[['name1', 'imagenum1', 'name2', 'imagenum2']]
match_dev_test_df['label'] = 1

mismatch_dev_test_df['label'] = 0
mismatch_dev_train_df['label'] = 0
mismatch_dev_val_df['label'] = 0

train_df = pd.concat([match_dev_train_df, mismatch_dev_train_df], ignore_index=True).sample(frac=1).reset_index(drop=True)
val_df = pd.concat([match_dev_val_df, mismatch_dev_val_df], ignore_index=True).sample(frac=1).reset_index(drop=True)
test_df = pd.concat([match_dev_test_df, mismatch_dev_test_df], ignore_index=True).sample(frac=1).reset_index(drop=True)

# %% [markdown]
# ## Generating Many Pairs

# %%
def generate_matched_pairs(people_df: pd.DataFrame, max_pairs: int = None) -> pd.DataFrame:
    matched_pairs = []
    for _, row in people_df.iterrows():
        name = row['name']
        num_images = int(row['images'])
        
        matched_pairs += [(name, i, name, j, 1) for i, j in combinations(range(1, num_images + 1), 2)]

    random.shuffle(matched_pairs)
    matched_pairs = matched_pairs[:min(max_pairs, len(matched_pairs))] if max_pairs else matched_pairs
    return pd.DataFrame(matched_pairs, columns=['name1', 'imagenum1', 'name2', 'imagenum2', 'label'])



def generate_mismatched_pairs(people_df: pd.DataFrame, pairs_per_person: int = 5, max_pairs: int = None) -> pd.DataFrame:
    mismatched_pairs = []
    mismatched_pairs_set = {}
    names = people_df['name'].tolist()
    name_to_count = dict(zip(people_df['name'], people_df['images']))

    for name1 in names:
        possible_others = [n for n in names if n != name1]
        sampled_others = random.sample(possible_others, min(len(possible_others), pairs_per_person))

        for name2 in sampled_others:
            if((name1, name2) in mismatched_pairs_set or (name2, name1) in mismatched_pairs_set):
                continue
            mismatched_pairs_set[(name1, name2)] = True
            num1 = name_to_count[name1]
            num2 = name_to_count[name2]
            mismatched_pairs += [(name1, img1, name2, img2, 0) for img1, img2 in product(range(1, num1 + 1), range(1, num2 + 1))]

    random.shuffle(mismatched_pairs)
    mismatched_pairs = mismatched_pairs[:min(max_pairs, len(mismatched_pairs))] if max_pairs else mismatched_pairs
    return pd.DataFrame(mismatched_pairs, columns=['name1', 'imagenum1', 'name2', 'imagenum2', 'label'])

# %%
num_pairs = 100000
people_train_df = pd.read_csv(os.path.join(dataset_path, "peopleDevTrain.csv")).sort_index()
people_train_df, people_val_df = train_test_split(people_train_df, test_size=0.2, random_state=42)
people_test_df = pd.read_csv(os.path.join(dataset_path, "peopleDevTest.csv")).sort_index()

people_train_df = people_train_df.reset_index(drop=True)
people_val_df = people_val_df.reset_index(drop=True)
people_test_df = people_test_df.reset_index(drop=True)

mismatch_dev_test_df = generate_mismatched_pairs(people_test_df, pairs_per_person=10, max_pairs=(int(num_pairs*0.1)))
match_dev_test_df = generate_matched_pairs(people_test_df, max_pairs=int(num_pairs*0.1))
mismatch_dev_val_df = generate_mismatched_pairs(people_val_df, pairs_per_person=10, max_pairs=int(num_pairs*0.1))
match_dev_val_df = generate_matched_pairs(people_val_df, max_pairs=int(num_pairs*0.1))



train_df = pd.concat([match_dev_train_df, mismatch_dev_train_df], ignore_index=True).sample(frac=1).reset_index(drop=True)
val_df = pd.concat([match_dev_val_df, mismatch_dev_val_df], ignore_index=True).sample(frac=1).reset_index(drop=True)
test_df = pd.concat([match_dev_test_df, mismatch_dev_test_df], ignore_index=True).sample(frac=1).reset_index(drop=True)

# %% [markdown]
# ## Loaders

# %%
IMAGE_SIZE = 105
transform = transforms.Compose([
    transforms.Grayscale(num_output_channels=1),  # Convert to black and white
    transforms.Resize((IMAGE_SIZE, IMAGE_SIZE)),               # Resize to match model input
    transforms.ToTensor()                        # Converts to tensor and scales to [0, 1]
])


class SiameseDataset(Dataset):
    def __init__(self, people_df, transform=None, root_dir="", mode="train", num_pairs=10000):
        self.people_df = people_df
        self.transform = transform
        self.root_dir = root_dir
        self.mode = mode
        self.num_pairs = num_pairs
        
        if mode != "train":
            # For fixed val/test sets
            self.pairs_df = people_df

        else:
            # Prepare name -> image count mapping
            self.name_to_imgs = {
                row['name']: list(range(1, int(row['images']) + 1))
                for _, row in people_df.iterrows() if row['images'] >= 2
            }
            self.names = list(self.name_to_imgs.keys())
    
    def __len__(self):
        return self.num_pairs if self.mode == "train" else len(self.pairs_df)

    def __getitem__(self, idx):
        if self.mode != "train":
            row = self.pairs_df.iloc[idx]
            name1, imgnum1 = row['name1'], int(row['imagenum1'])
            name2, imgnum2 = row['name2'], int(row['imagenum2'])
            label = row['label']
        else:
            is_match = random.random() < 0.5
            if is_match:
                name = random.choice(self.names)
                imgs = random.sample(self.name_to_imgs[name], 2)
                name1, imgnum1, name2, imgnum2, label = name, imgs[0], name, imgs[1], 1
            else:
                name1, name2 = random.sample(self.names, 2)
                imgnum1 = random.choice(self.name_to_imgs[name1])
                imgnum2 = random.choice(self.name_to_imgs[name2])
                label = 0

        path1 = os.path.join(self.root_dir, f"{name1}_{imgnum1:04d}.jpg")
        path2 = os.path.join(self.root_dir, f"{name2}_{imgnum2:04d}.jpg")

        image1 = Image.open(path1).convert("RGB")
        image2 = Image.open(path2).convert("RGB")

        if self.transform:
            image1 = self.transform(image1)
            image2 = self.transform(image2)

        return image1, image2, torch.tensor(label, dtype=torch.float32)

# %% [markdown]
# # Initializing The Network

# %%
last_layer = 512
class SingularCNN(nn.Module):
    def __init__(self):
        super(SingularCNN, self).__init__()
        
        self.cnn = nn.Sequential(
            nn.BatchNorm2d(1),
            nn.Conv2d(1, 64, kernel_size=10), 
            nn.ReLU(),
            nn.MaxPool2d(2, stride=2),

            nn.Conv2d(64, 128, kernel_size=7),
            nn.ReLU(),
            nn.MaxPool2d(2, stride=2),

            nn.Conv2d(128, 128, kernel_size=4),
            nn.ReLU(),
            nn.MaxPool2d(2),

            # nn.Conv2d(128, 256, kernel_size=4),
            nn.ReLU(),
            nn.Flatten(),
            nn.Linear(128 * 9 * 9, last_layer),  # Fully connected layer
            nn.Tanh(),  # Activation function
        )

    def forward(self, X):
        return self.cnn(X)
    
    def _initialize_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                init.normal_(m.weight, mean=0.0, std=1e-2)
                if m.bias is not None:
                    init.normal_(m.bias, mean=0.5, std=1e-2)
            elif isinstance(m, nn.Linear):
                init.normal_(m.weight, mean=0.0, std=2e-1)
                if m.bias is not None:
                    init.normal_(m.bias, mean=0.5, std=1e-2)
    
    


class TwinCNN(nn.Module):
    def __init__(self):
        super(TwinCNN, self).__init__()
        
        # Share the same SiameseCNN instance for both branches
        self.scnn1 = SingularCNN()
        self.scnn2 = self.scnn1  # Use the same SiameseCNN instance for shared weights

        self.fc = nn.Sequential(
            nn.Linear(last_layer, 1),
            nn.Sigmoid()  # As used in the original paper
        )
        
    def forward(self, X1, X2):
        out1 = self.scnn1(X1)
        out2 = self.scnn2(X2)  # Same weights are used here due to reference
        out = torch.abs(out1 - out2)
        return self.fc(out)

# %% [markdown]
# ## Training The Twins

# %%
import time

def train(model, train_loader, val_loader, test_loader, loss_fn, optimizer, device, epochs=10, batch_size=32):
    train_losses = []
    train_accuracies = []
    val_losses = []
    val_accuracies = []
    test_accuracies = []
    test_losses = []

    start_time = time.time()  # Start timer

    for epoch in range(epochs):
        model.train()
        train_loss = 0
        train_correct = 0
        train_total = 0
        num_batches = 0  

        for inputs1, inputs2, targets in train_loader:
            inputs1, inputs2, targets = inputs1.to(device), inputs2.to(device), targets.to(device)
            num_batches += 1
            optimizer.zero_grad()
            outputs = model(inputs1, inputs2)
            loss = loss_fn(outputs, targets)
            loss.backward()
            optimizer.step()
            train_loss += loss.item()
            with torch.no_grad():
                predicted = (outputs > 0.5)
                train_total += targets.shape[0]
                train_correct += predicted.eq(targets).sum().item()

        avg_train_loss = train_loss / num_batches
        train_losses.append(avg_train_loss)
        train_accuracies.append(100. * train_correct / train_total)

        # Validation
        model.eval()
        val_loss = 0
        val_correct = 0
        val_total = 0
        num_batches = 0

        with torch.no_grad():
            for inputs1, inputs2, targets in val_loader:
                inputs1, inputs2, targets = inputs1.to(device), inputs2.to(device), targets.to(device)
                num_batches += 1
                outputs = model(inputs1, inputs2)
                loss = loss_fn(outputs, targets)
                val_loss += loss.item()
                predicted = (outputs > 0.5)
                val_total += targets.shape[0]
                val_correct += predicted.eq(targets).sum().item()

        avg_val_loss = val_loss / num_batches
        val_accuracy = 100. * val_correct / val_total
        val_losses.append(avg_val_loss)
        val_accuracies.append(val_accuracy)

        # Test
        model.eval()
        test_loss = 0
        test_correct = 0
        test_total = 0
        num_batches = 0
        with torch.no_grad():
            for inputs1, inputs2, targets in test_loader:
                inputs1, inputs2, targets = inputs1.to(device), inputs2.to(device), targets.to(device)
                num_batches += 1
                outputs = model(inputs1, inputs2)
                loss = loss_fn(outputs, targets)
                test_loss += loss.item()

                predicted = (outputs > 0.5)
                test_total += targets.shape[0]
                test_correct += predicted.eq(targets).sum().item()
        test_accuracies.append(100. * test_correct / test_total)
        test_losses.append(test_loss / num_batches)

        elapsed_time = (time.time() - start_time) / 60  # Minutes since training started

        print(f"[{elapsed_time:.2f} min] Epoch {epoch+1}/{epochs} "
              f"Train Loss: {avg_train_loss:.4f} "
              f"Val Loss: {avg_val_loss:.4f} "
              f"Val Accuracy: {val_accuracy:.2f}% "
              f"Test Accuracy: {test_accuracies[-1]:.2f}% ")

    return train_losses, train_accuracies, val_losses, val_accuracies, test_losses, test_accuracies

# %% [markdown]
# ## Actual Training

# %%
import gc

# Delete your tensors or model if you're done with them
del model
del optimizer
# del any_other_tensor

gc.collect()                # Collect garbage
torch.cuda.empty_cache()    # Free up unused cached memory

# %%
model = TwinCNN()
device = torch.device("cuda" if is_cuda_available() else "cpu")
model.to(device)
# Out:
# TwinCNN(
#   (scnn1): SingularCNN(
#     (cnn): Sequential(
#       (0): BatchNorm2d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (1): Conv2d(1, 64, kernel_size=(10, 10), stride=(1, 1))
#       (2): ReLU()
#       (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (4): Conv2d(64, 128, kernel_size=(7, 7), stride=(1, 1))
#       (5): ReLU()
#       (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (7): Conv2d(128, 128, kernel_size=(4, 4), stride=(1, 1))
#       (8): ReLU()
#       (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (10): ReLU()
#       (11): Flatten(start_dim=1, end_dim=-1)
#       (12): Linear(in_features=10368, out_features=512, bias=True)
#       (13): Tanh()
#     )
#   )
#   (scnn2): SingularCNN(
#     (cnn): Sequential(
#       (0): BatchNorm2d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (1): Conv2d(1, 64, kernel_size=(10, 10), stride=(1, 1))
#       (2): ReLU()
#       (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (4): Conv2d(64, 128, kernel_size=(7, 7), stride=(1, 1))
#       (5): ReLU()
#       (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (7): Conv2d(128, 128, kernel_size=(4, 4), stride=(1, 1))
#       (8): ReLU()
#       (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (10): ReLU()
#       (11): Flatten(start_dim=1, end_dim=-1)
#       (12): Linear(in_features=10368, out_features=512, bias=True)
#       (13): Tanh()
#     )
#   )
#   (fc): Sequential(
#     (0): Linear(in_features=512, out_features=1, bias=True)
#     (1): Sigmoid()
#   )
# )

# %%
# Define the path to save the ONNX model
onnx_model_path = os.path.join(cwd, "model.onnx")

# Dummy input for the model (batch size of 1, grayscale image, IMAGE_SIZE x IMAGE_SIZE)
dummy_input1 = torch.randn(1, 1, IMAGE_SIZE, IMAGE_SIZE, device=device)
dummy_input2 = torch.randn(1, 1, IMAGE_SIZE, IMAGE_SIZE, device=device)

# Export the model to ONNX format
torch.onnx.export(
    model, 
    (dummy_input1, dummy_input2), 
    onnx_model_path, 
    export_params=True, 
    opset_version=11, 
    do_constant_folding=True, 
    input_names=['input1', 'input2'], 
    output_names=['output']
)

# %%
batch_size = 128
initial_lr = 0.0001
optimizer = torch.optim.Adam(model.parameters(), lr=initial_lr, weight_decay=1e-4)
loss_fn = nn.BCELoss()



train_dataset = SiameseDataset(people_train_df, transform=transform, root_dir=images_path, num_pairs=num_pairs*0.6)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=4, mode="train")
val_dataset = SiameseDataset(val_df, transform=transform, root_dir=images_path)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, num_workers=4, model="val")
test_dataset = SiameseDataset(test_df, transform=transform, root_dir=images_path)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, num_workers=4, model="test")


train_losses, train_accuracies, val_losses, val_accuracies, test_losses, test_accuracies = train(
    model,
    people_train_df,
    val_df,
    test_df,
    loss_fn,
    optimizer,
    device,
    epochs=100,
    batch_size=batch_size
)
# Out:
# [0.16 min] Epoch 1/200 Train Loss: 0.5799 Val Loss: 0.6167 Val Accuracy: 68.20%Test Accuracy: 67.95%
# [0.30 min] Epoch 2/200 Train Loss: 0.4193 Val Loss: 0.6495 Val Accuracy: 67.15%Test Accuracy: 68.20%
# [0.45 min] Epoch 3/200 Train Loss: 0.3023 Val Loss: 0.6515 Val Accuracy: 68.75%Test Accuracy: 70.40%
# [0.59 min] Epoch 4/200 Train Loss: 0.2390 Val Loss: 0.7086 Val Accuracy: 65.85%Test Accuracy: 66.60%
# [0.74 min] Epoch 5/200 Train Loss: 0.1794 Val Loss: 0.7753 Val Accuracy: 64.75%Test Accuracy: 66.35%
# [0.89 min] Epoch 6/200 Train Loss: 0.1355 Val Loss: 0.7040 Val Accuracy: 66.60%Test Accuracy: 68.40%
# [1.03 min] Epoch 7/200 Train Loss: 0.0997 Val Loss: 0.8055 Val Accuracy: 64.35%Test Accuracy: 65.95%
# [1.18 min] Epoch 8/200 Train Loss: 0.0711 Val Loss: 0.8622 Val Accuracy: 63.40%Test Accuracy: 66.65%
# [1.33 min] Epoch 9/200 Train Loss: 0.0490 Val Loss: 0.8866 Val Accuracy: 62.70%Test Accuracy: 66.20%
# [1.47 min] Epoch 10/200 Train Loss: 0.0327 Val Loss: 0.9213 Val Accuracy: 63.55%Test Accuracy: 66.60%
# [1.62 min] Epoch 11/200 Train Loss: 0.0229 Val Loss: 0.9048 Val Accuracy: 64.35%Test Accuracy: 67.90%
# [1.77 min] Epoch 12/200 Train Loss: 0.0168 Val Loss: 0.9445 Val Accuracy: 64.40%Test Accuracy: 67.85%
# [1.92 min] Epoch 13/200 Train Loss: 0.0132 Val Loss: 0.9249 Val Accuracy: 64.40%Test Accuracy: 68.50%
# [2.06 min] Epoch 14/200 Train Loss: 0.0105 Val Loss: 1.0010 Val Accuracy: 64.30%Test Accuracy: 67.95%
# [2.22 min] Epoch 15/200 Train Loss: 0.0087 Val Loss: 1.0699 Val Accuracy: 62.60%Test Accuracy: 66.20%
# [2.36 min] Epoch 16/200 Train Loss: 0.0075 Val Loss: 1.0065 Val Accuracy: 63.95%Test Accuracy: 67.90%
# [2.51 min] Epoch 17/200 Train Loss: 0.0064 Val Loss: 1.0401 Val Accuracy: 63.65%Test Accuracy: 67.90%
# [2.66 min] Epoch 18/200 Train Loss: 0.0056 Val Loss: 1.0657 Val Accuracy: 63.00%Test Accuracy: 67.65%
# [2.81 min] Epoch 19/200 Train Loss: 0.0049 Val Loss: 1.1323 Val Accuracy: 62.60%Test Accuracy: 66.35%
# [2.95 min] Epoch 20/200 Train Loss: 0.0043 Val Loss: 1.1385 Val Accuracy: 62.50%Test Accuracy: 66.60%
# [3.10 min] Epoch 21/200 Train Loss: 0.0039 Val Loss: 1.1113 Val Accuracy: 62.95%Test Accuracy: 67.00%
# [3.25 min] Epoch 22/200 Train Loss: 0.0035 Val Loss: 1.1541 Val Accuracy: 62.45%Test Accuracy: 66.75%
# [3.39 min] Epoch 23/200 Train Loss: 0.0032 Val Loss: 1.1661 Val Accuracy: 62.50%Test Accuracy: 66.75%
# [3.54 min] Epoch 24/200 Train Loss: 0.0029 Val Loss: 1.1223 Val Accuracy: 63.20%Test Accuracy: 67.50%
# [3.68 min] Epoch 25/200 Train Loss: 0.0027 Val Loss: 1.1639 Val Accuracy: 62.55%Test Accuracy: 67.15%
# [3.83 min] Epoch 26/200 Train Loss: 0.0025 Val Loss: 1.1830 Val Accuracy: 62.35%Test Accuracy: 66.75%
# [3.97 min] Epoch 27/200 Train Loss: 0.0023 Val Loss: 1.1604 Val Accuracy: 62.80%Test Accuracy: 67.20%
# [4.12 min] Epoch 28/200 Train Loss: 0.0022 Val Loss: 1.1842 Val Accuracy: 62.75%Test Accuracy: 67.20%
# [4.27 min] Epoch 29/200 Train Loss: 0.0020 Val Loss: 1.1702 Val Accuracy: 63.05%Test Accuracy: 67.35%
# [4.42 min] Epoch 30/200 Train Loss: 0.0019 Val Loss: 1.1791 Val Accuracy: 62.95%Test Accuracy: 67.40%
# [4.56 min] Epoch 31/200 Train Loss: 0.0018 Val Loss: 1.2395 Val Accuracy: 62.20%Test Accuracy: 66.75%
# [4.71 min] Epoch 32/200 Train Loss: 0.0017 Val Loss: 1.2111 Val Accuracy: 62.50%Test Accuracy: 67.10%
# [4.85 min] Epoch 33/200 Train Loss: 0.0016 Val Loss: 1.2187 Val Accuracy: 62.45%Test Accuracy: 67.20%
# [5.00 min] Epoch 34/200 Train Loss: 0.0015 Val Loss: 1.2367 Val Accuracy: 62.30%Test Accuracy: 67.05%
# [5.15 min] Epoch 35/200 Train Loss: 0.0014 Val Loss: 1.2365 Val Accuracy: 62.50%Test Accuracy: 66.85%
# [5.33 min] Epoch 36/200 Train Loss: 0.0014 Val Loss: 1.2312 Val Accuracy: 62.30%Test Accuracy: 67.25%
# [5.48 min] Epoch 37/200 Train Loss: 0.0013 Val Loss: 1.2650 Val Accuracy: 62.35%Test Accuracy: 66.75%
# [5.62 min] Epoch 38/200 Train Loss: 0.0012 Val Loss: 1.2893 Val Accuracy: 62.10%Test Accuracy: 66.35%
# [5.77 min] Epoch 39/200 Train Loss: 0.0012 Val Loss: 1.2646 Val Accuracy: 62.55%Test Accuracy: 67.40%
# [5.92 min] Epoch 40/200 Train Loss: 0.0011 Val Loss: 1.2537 Val Accuracy: 62.60%Test Accuracy: 67.35%
# [6.06 min] Epoch 41/200 Train Loss: 0.0011 Val Loss: 1.2754 Val Accuracy: 62.20%Test Accuracy: 67.15%
# [6.24 min] Epoch 42/200 Train Loss: 0.0010 Val Loss: 1.2939 Val Accuracy: 62.25%Test Accuracy: 66.90%
# [6.39 min] Epoch 43/200 Train Loss: 0.0010 Val Loss: 1.2826 Val Accuracy: 62.45%Test Accuracy: 67.50%
# [6.53 min] Epoch 44/200 Train Loss: 0.0010 Val Loss: 1.2879 Val Accuracy: 62.35%Test Accuracy: 67.20%
# [6.68 min] Epoch 45/200 Train Loss: 0.0009 Val Loss: 1.2950 Val Accuracy: 62.60%Test Accuracy: 66.90%
# [6.83 min] Epoch 46/200 Train Loss: 0.0009 Val Loss: 1.3100 Val Accuracy: 62.25%Test Accuracy: 66.95%
# [6.97 min] Epoch 47/200 Train Loss: 0.0008 Val Loss: 1.2766 Val Accuracy: 62.85%Test Accuracy: 67.65%
# [7.12 min] Epoch 48/200 Train Loss: 0.0008 Val Loss: 1.3400 Val Accuracy: 62.10%Test Accuracy: 66.50%
# [7.29 min] Epoch 49/200 Train Loss: 0.0008 Val Loss: 1.3205 Val Accuracy: 62.50%Test Accuracy: 67.10%
# [7.44 min] Epoch 50/200 Train Loss: 0.0008 Val Loss: 1.3234 Val Accuracy: 62.15%Test Accuracy: 67.05%
# [7.59 min] Epoch 51/200 Train Loss: 0.0008 Val Loss: 1.3097 Val Accuracy: 62.55%Test Accuracy: 67.25%
# [7.74 min] Epoch 52/200 Train Loss: 0.0007 Val Loss: 1.3344 Val Accuracy: 62.20%Test Accuracy: 67.05%
# [7.89 min] Epoch 53/200 Train Loss: 0.0007 Val Loss: 1.3502 Val Accuracy: 62.05%Test Accuracy: 66.70%
# [8.03 min] Epoch 54/200 Train Loss: 0.0007 Val Loss: 1.3355 Val Accuracy: 62.50%Test Accuracy: 67.05%
# [8.20 min] Epoch 55/200 Train Loss: 0.0006 Val Loss: 1.3212 Val Accuracy: 62.30%Test Accuracy: 67.45%
# [8.35 min] Epoch 56/200 Train Loss: 0.0006 Val Loss: 1.3214 Val Accuracy: 62.75%Test Accuracy: 67.40%
# [8.49 min] Epoch 57/200 Train Loss: 0.0006 Val Loss: 1.3124 Val Accuracy: 62.35%Test Accuracy: 67.50%
# [8.65 min] Epoch 58/200 Train Loss: 0.0006 Val Loss: 1.3317 Val Accuracy: 62.55%Test Accuracy: 67.10%
# [8.79 min] Epoch 59/200 Train Loss: 0.0006 Val Loss: 1.3396 Val Accuracy: 62.65%Test Accuracy: 66.90%
# [8.94 min] Epoch 60/200 Train Loss: 0.0006 Val Loss: 1.3378 Val Accuracy: 62.75%Test Accuracy: 67.25%
# [9.08 min] Epoch 61/200 Train Loss: 0.0005 Val Loss: 1.3495 Val Accuracy: 62.55%Test Accuracy: 66.70%
# [9.25 min] Epoch 62/200 Train Loss: 0.0005 Val Loss: 1.3593 Val Accuracy: 62.60%Test Accuracy: 67.10%
# [9.40 min] Epoch 63/200 Train Loss: 0.0005 Val Loss: 1.3075 Val Accuracy: 62.70%Test Accuracy: 67.85%
# [9.56 min] Epoch 64/200 Train Loss: 0.0005 Val Loss: 1.3781 Val Accuracy: 62.45%Test Accuracy: 67.10%
# [9.72 min] Epoch 65/200 Train Loss: 0.0005 Val Loss: 1.3532 Val Accuracy: 62.20%Test Accuracy: 67.35%
# [9.87 min] Epoch 66/200 Train Loss: 0.0005 Val Loss: 1.3837 Val Accuracy: 62.45%Test Accuracy: 67.40%
# [10.03 min] Epoch 67/200 Train Loss: 0.0005 Val Loss: 1.3371 Val Accuracy: 62.70%Test Accuracy: 67.80%
# [10.18 min] Epoch 68/200 Train Loss: 0.0005 Val Loss: 1.3474 Val Accuracy: 62.70%Test Accuracy: 67.75%
# [10.36 min] Epoch 69/200 Train Loss: 0.0004 Val Loss: 1.3371 Val Accuracy: 62.75%Test Accuracy: 67.70%
# [10.52 min] Epoch 70/200 Train Loss: 0.0004 Val Loss: 1.3776 Val Accuracy: 62.30%Test Accuracy: 67.45%
# [10.68 min] Epoch 71/200 Train Loss: 0.0004 Val Loss: 1.3604 Val Accuracy: 62.75%Test Accuracy: 67.60%
# [10.84 min] Epoch 72/200 Train Loss: 0.0004 Val Loss: 1.3767 Val Accuracy: 62.55%Test Accuracy: 67.15%
# [10.99 min] Epoch 73/200 Train Loss: 0.0004 Val Loss: 1.3694 Val Accuracy: 62.50%Test Accuracy: 67.30%
# [11.14 min] Epoch 74/200 Train Loss: 0.0004 Val Loss: 1.3597 Val Accuracy: 62.60%Test Accuracy: 67.80%
# [11.32 min] Epoch 75/200 Train Loss: 0.0004 Val Loss: 1.3574 Val Accuracy: 62.60%Test Accuracy: 67.70%
# [11.48 min] Epoch 76/200 Train Loss: 0.0004 Val Loss: 1.4035 Val Accuracy: 62.50%Test Accuracy: 67.40%
# [11.65 min] Epoch 77/200 Train Loss: 0.0004 Val Loss: 1.3998 Val Accuracy: 62.00%Test Accuracy: 67.40%
# [11.81 min] Epoch 78/200 Train Loss: 0.0004 Val Loss: 1.3393 Val Accuracy: 62.95%Test Accuracy: 67.75%
# [11.97 min] Epoch 79/200 Train Loss: 0.0004 Val Loss: 1.4326 Val Accuracy: 62.05%Test Accuracy: 66.55%
# [12.12 min] Epoch 80/200 Train Loss: 0.0004 Val Loss: 1.4032 Val Accuracy: 62.25%Test Accuracy: 67.25%
# [12.28 min] Epoch 81/200 Train Loss: 0.0003 Val Loss: 1.4121 Val Accuracy: 62.40%Test Accuracy: 67.30%
# [12.43 min] Epoch 82/200 Train Loss: 0.0003 Val Loss: 1.3460 Val Accuracy: 62.95%Test Accuracy: 67.80%
# [12.59 min] Epoch 83/200 Train Loss: 0.0003 Val Loss: 1.4160 Val Accuracy: 62.30%Test Accuracy: 67.40%
# [12.75 min] Epoch 84/200 Train Loss: 0.0003 Val Loss: 1.3908 Val Accuracy: 62.60%Test Accuracy: 67.45%
# [12.90 min] Epoch 85/200 Train Loss: 0.0003 Val Loss: 1.4373 Val Accuracy: 62.45%Test Accuracy: 67.30%
# [13.04 min] Epoch 86/200 Train Loss: 0.0003 Val Loss: 1.3775 Val Accuracy: 62.35%Test Accuracy: 67.80%
# [13.21 min] Epoch 87/200 Train Loss: 0.0003 Val Loss: 1.3355 Val Accuracy: 63.50%Test Accuracy: 67.70%
# [13.37 min] Epoch 88/200 Train Loss: 0.0003 Val Loss: 1.3951 Val Accuracy: 62.55%Test Accuracy: 67.50%
# [13.53 min] Epoch 89/200 Train Loss: 0.0003 Val Loss: 1.4341 Val Accuracy: 62.15%Test Accuracy: 66.80%
# [13.71 min] Epoch 90/200 Train Loss: 0.0003 Val Loss: 1.4006 Val Accuracy: 62.55%Test Accuracy: 67.65%
# [13.88 min] Epoch 91/200 Train Loss: 0.0003 Val Loss: 1.3807 Val Accuracy: 63.10%Test Accuracy: 67.85%
# [14.04 min] Epoch 92/200 Train Loss: 0.0003 Val Loss: 1.4571 Val Accuracy: 62.25%Test Accuracy: 66.85%
# [14.19 min] Epoch 93/200 Train Loss: 0.0003 Val Loss: 1.3961 Val Accuracy: 62.70%Test Accuracy: 67.70%
# [14.33 min] Epoch 94/200 Train Loss: 0.0003 Val Loss: 1.4826 Val Accuracy: 62.05%Test Accuracy: 66.60%
# [14.48 min] Epoch 95/200 Train Loss: 0.0003 Val Loss: 1.3653 Val Accuracy: 63.20%Test Accuracy: 67.75%
# [14.64 min] Epoch 96/200 Train Loss: 0.0003 Val Loss: 1.3673 Val Accuracy: 63.35%Test Accuracy: 68.15%
# [14.79 min] Epoch 97/200 Train Loss: 0.0003 Val Loss: 1.4118 Val Accuracy: 62.75%Test Accuracy: 67.50%
# [14.94 min] Epoch 98/200 Train Loss: 0.0003 Val Loss: 1.4477 Val Accuracy: 62.35%Test Accuracy: 67.35%
# [15.09 min] Epoch 99/200 Train Loss: 0.0003 Val Loss: 1.3855 Val Accuracy: 62.65%Test Accuracy: 67.80%
# [15.28 min] Epoch 100/200 Train Loss: 0.0003 Val Loss: 1.4643 Val Accuracy: 62.10%Test Accuracy: 67.35%
# [15.43 min] Epoch 101/200 Train Loss: 0.0002 Val Loss: 1.4245 Val Accuracy: 62.75%Test Accuracy: 67.40%
# [15.58 min] Epoch 102/200 Train Loss: 0.0002 Val Loss: 1.4056 Val Accuracy: 62.65%Test Accuracy: 67.65%
# [15.73 min] Epoch 103/200 Train Loss: 0.0002 Val Loss: 1.5203 Val Accuracy: 62.10%Test Accuracy: 66.40%
# [15.88 min] Epoch 104/200 Train Loss: 0.0002 Val Loss: 1.4321 Val Accuracy: 62.35%Test Accuracy: 67.35%
# [16.03 min] Epoch 105/200 Train Loss: 0.0002 Val Loss: 1.4898 Val Accuracy: 62.05%Test Accuracy: 66.70%
# [16.18 min] Epoch 106/200 Train Loss: 0.0003 Val Loss: 1.3503 Val Accuracy: 63.05%Test Accuracy: 67.70%
# [16.32 min] Epoch 107/200 Train Loss: 0.0002 Val Loss: 1.4519 Val Accuracy: 62.80%Test Accuracy: 67.55%
# [16.47 min] Epoch 108/200 Train Loss: 0.0002 Val Loss: 1.4445 Val Accuracy: 62.60%Test Accuracy: 67.15%
# [16.62 min] Epoch 109/200 Train Loss: 0.0002 Val Loss: 1.4111 Val Accuracy: 63.15%Test Accuracy: 67.65%
# [16.77 min] Epoch 110/200 Train Loss: 0.0002 Val Loss: 1.3132 Val Accuracy: 64.05%Test Accuracy: 69.05%
# [16.91 min] Epoch 111/200 Train Loss: 0.0002 Val Loss: 1.3791 Val Accuracy: 63.45%Test Accuracy: 68.55%
# [17.06 min] Epoch 112/200 Train Loss: 0.0002 Val Loss: 1.4847 Val Accuracy: 62.25%Test Accuracy: 67.55%
# [17.21 min] Epoch 113/200 Train Loss: 0.0002 Val Loss: 1.4160 Val Accuracy: 63.25%Test Accuracy: 67.95%
# [17.35 min] Epoch 114/200 Train Loss: 0.0002 Val Loss: 1.3654 Val Accuracy: 63.25%Test Accuracy: 68.70%
# [17.50 min] Epoch 115/200 Train Loss: 0.0002 Val Loss: 1.3838 Val Accuracy: 63.15%Test Accuracy: 67.80%
# [17.64 min] Epoch 116/200 Train Loss: 0.0002 Val Loss: 1.3142 Val Accuracy: 64.65%Test Accuracy: 69.15%
# [17.79 min] Epoch 117/200 Train Loss: 0.0002 Val Loss: 1.3951 Val Accuracy: 63.50%Test Accuracy: 68.00%
# [17.93 min] Epoch 118/200 Train Loss: 0.0002 Val Loss: 1.4787 Val Accuracy: 62.80%Test Accuracy: 68.25%
# [18.08 min] Epoch 119/200 Train Loss: 0.0002 Val Loss: 1.4540 Val Accuracy: 62.60%Test Accuracy: 67.45%
# [18.22 min] Epoch 120/200 Train Loss: 0.0002 Val Loss: 1.4584 Val Accuracy: 63.00%Test Accuracy: 67.85%
# [18.37 min] Epoch 121/200 Train Loss: 0.0002 Val Loss: 1.5688 Val Accuracy: 61.85%Test Accuracy: 66.45%
# [18.51 min] Epoch 122/200 Train Loss: 0.0002 Val Loss: 1.5884 Val Accuracy: 61.50%Test Accuracy: 66.55%
# [18.66 min] Epoch 123/200 Train Loss: 0.0003 Val Loss: 1.1575 Val Accuracy: 66.60%Test Accuracy: 70.40%
# [18.80 min] Epoch 124/200 Train Loss: 0.6059 Val Loss: 0.6934 Val Accuracy: 50.00%Test Accuracy: 50.05%
# [18.94 min] Epoch 125/200 Train Loss: 0.6934 Val Loss: 0.6934 Val Accuracy: 50.00%Test Accuracy: 50.00%
# [19.09 min] Epoch 126/200 Train Loss: 0.6934 Val Loss: 0.6934 Val Accuracy: 50.00%Test Accuracy: 50.00%
# [19.24 min] Epoch 127/200 Train Loss: 0.6934 Val Loss: 0.6934 Val Accuracy: 50.00%Test Accuracy: 50.00%
# [19.38 min] Epoch 128/200 Train Loss: 0.6934 Val Loss: 0.6934 Val Accuracy: 50.00%Test Accuracy: 50.00%
# [19.52 min] Epoch 129/200 Train Loss: 0.6934 Val Loss: 0.6933 Val Accuracy: 50.00%Test Accuracy: 50.00%
# [19.67 min] Epoch 130/200 Train Loss: 0.6933 Val Loss: 0.6933 Val Accuracy: 50.00%Test Accuracy: 50.00%
# [19.81 min] Epoch 131/200 Train Loss: 0.6933 Val Loss: 0.6933 Val Accuracy: 50.00%Test Accuracy: 50.00%
# [19.95 min] Epoch 132/200 Train Loss: 0.6933 Val Loss: 0.6933 Val Accuracy: 50.00%Test Accuracy: 50.00%
# [20.10 min] Epoch 133/200 Train Loss: 0.6933 Val Loss: 0.6933 Val Accuracy: 50.00%Test Accuracy: 50.00%
# [20.25 min] Epoch 134/200 Train Loss: 0.6933 Val Loss: 0.6933 Val Accuracy: 50.00%Test Accuracy: 50.00%
# [20.39 min] Epoch 135/200 Train Loss: 0.6933 Val Loss: 0.6933 Val Accuracy: 50.00%Test Accuracy: 50.00%
# [20.53 min] Epoch 136/200 Train Loss: 0.6933 Val Loss: 0.6933 Val Accuracy: 50.00%Test Accuracy: 50.00%
# [20.68 min] Epoch 137/200 Train Loss: 0.6933 Val Loss: 0.6933 Val Accuracy: 50.00%Test Accuracy: 50.00%
# [20.83 min] Epoch 138/200 Train Loss: 0.6932 Val Loss: 0.6932 Val Accuracy: 50.00%Test Accuracy: 50.05%
# [20.97 min] Epoch 139/200 Train Loss: 0.6933 Val Loss: 0.6932 Val Accuracy: 50.00%Test Accuracy: 50.00%
# [21.13 min] Epoch 140/200 Train Loss: 0.6932 Val Loss: 0.6932 Val Accuracy: 50.00%Test Accuracy: 50.00%
# [21.28 min] Epoch 141/200 Train Loss: 0.6932 Val Loss: 0.6932 Val Accuracy: 50.00%Test Accuracy: 50.00%
# [21.42 min] Epoch 142/200 Train Loss: 0.6932 Val Loss: 0.6932 Val Accuracy: 50.00%Test Accuracy: 50.00%
# [21.57 min] Epoch 143/200 Train Loss: 0.6932 Val Loss: 0.6932 Val Accuracy: 50.00%Test Accuracy: 50.00%
# [21.71 min] Epoch 144/200 Train Loss: 0.6932 Val Loss: 0.6932 Val Accuracy: 50.00%Test Accuracy: 50.00%
# [21.86 min] Epoch 145/200 Train Loss: 0.6932 Val Loss: 0.6932 Val Accuracy: 50.00%Test Accuracy: 50.00%
# [22.00 min] Epoch 146/200 Train Loss: 0.6932 Val Loss: 0.6932 Val Accuracy: 50.00%Test Accuracy: 50.00%
# [22.15 min] Epoch 147/200 Train Loss: 0.6932 Val Loss: 0.6932 Val Accuracy: 50.00%Test Accuracy: 50.00%
# [22.30 min] Epoch 148/200 Train Loss: 0.6932 Val Loss: 0.6932 Val Accuracy: 50.00%Test Accuracy: 50.00%
# [22.44 min] Epoch 149/200 Train Loss: 0.6932 Val Loss: 0.6932 Val Accuracy: 50.00%Test Accuracy: 50.00%
# [22.59 min] Epoch 150/200 Train Loss: 0.6932 Val Loss: 0.6932 Val Accuracy: 50.00%Test Accuracy: 50.00%
# [22.73 min] Epoch 151/200 Train Loss: 0.6932 Val Loss: 0.6932 Val Accuracy: 50.00%Test Accuracy: 50.00%
# [22.88 min] Epoch 152/200 Train Loss: 0.6932 Val Loss: 0.6932 Val Accuracy: 50.00%Test Accuracy: 50.00%
# [23.02 min] Epoch 153/200 Train Loss: 0.6932 Val Loss: 0.6932 Val Accuracy: 50.00%Test Accuracy: 50.00%
# [23.17 min] Epoch 154/200 Train Loss: 0.6932 Val Loss: 0.6932 Val Accuracy: 50.00%Test Accuracy: 50.00%
# [23.31 min] Epoch 155/200 Train Loss: 0.6932 Val Loss: 0.6932 Val Accuracy: 50.00%Test Accuracy: 50.00%
# [23.46 min] Epoch 156/200 Train Loss: 0.6932 Val Loss: 0.6932 Val Accuracy: 50.00%Test Accuracy: 50.00%
# [23.60 min] Epoch 157/200 Train Loss: 0.6932 Val Loss: 0.6932 Val Accuracy: 50.00%Test Accuracy: 50.00%
# [23.75 min] Epoch 158/200 Train Loss: 0.6932 Val Loss: 0.6932 Val Accuracy: 50.00%Test Accuracy: 50.00%
# [23.89 min] Epoch 159/200 Train Loss: 0.6932 Val Loss: 0.6932 Val Accuracy: 50.00%Test Accuracy: 50.00%
# [24.04 min] Epoch 160/200 Train Loss: 0.6932 Val Loss: 0.6932 Val Accuracy: 50.00%Test Accuracy: 50.00%
# [24.18 min] Epoch 161/200 Train Loss: 0.6932 Val Loss: 0.6932 Val Accuracy: 50.00%Test Accuracy: 50.00%
# [24.33 min] Epoch 162/200 Train Loss: 0.6931 Val Loss: 0.6932 Val Accuracy: 50.00%Test Accuracy: 50.00%
# [24.47 min] Epoch 163/200 Train Loss: 0.6932 Val Loss: 0.6932 Val Accuracy: 50.00%Test Accuracy: 50.00%
# [24.62 min] Epoch 164/200 Train Loss: 0.6930 Val Loss: 0.6932 Val Accuracy: 50.00%Test Accuracy: 50.00%
# [24.76 min] Epoch 165/200 Train Loss: 0.6932 Val Loss: 0.6932 Val Accuracy: 50.00%Test Accuracy: 50.00%
# [24.91 min] Epoch 166/200 Train Loss: 0.6932 Val Loss: 0.6932 Val Accuracy: 50.00%Test Accuracy: 50.00%
# [25.06 min] Epoch 167/200 Train Loss: 0.6932 Val Loss: 0.6932 Val Accuracy: 50.00%Test Accuracy: 50.00%
# [25.20 min] Epoch 168/200 Train Loss: 0.6932 Val Loss: 0.6932 Val Accuracy: 50.00%Test Accuracy: 50.00%
# [25.35 min] Epoch 169/200 Train Loss: 0.6932 Val Loss: 0.6932 Val Accuracy: 50.00%Test Accuracy: 50.00%
# [25.49 min] Epoch 170/200 Train Loss: 0.6932 Val Loss: 0.6932 Val Accuracy: 50.00%Test Accuracy: 50.00%
# [25.64 min] Epoch 171/200 Train Loss: 0.6932 Val Loss: 0.6932 Val Accuracy: 50.00%Test Accuracy: 50.00%
# [25.78 min] Epoch 172/200 Train Loss: 0.6932 Val Loss: 0.6932 Val Accuracy: 50.00%Test Accuracy: 50.00%
# [25.93 min] Epoch 173/200 Train Loss: 0.6932 Val Loss: 0.6932 Val Accuracy: 50.00%Test Accuracy: 50.00%
# [26.08 min] Epoch 174/200 Train Loss: 0.6932 Val Loss: 0.6932 Val Accuracy: 50.00%Test Accuracy: 50.00%
# [26.22 min] Epoch 175/200 Train Loss: 0.6932 Val Loss: 0.6932 Val Accuracy: 50.00%Test Accuracy: 50.00%
# [26.37 min] Epoch 176/200 Train Loss: 0.6932 Val Loss: 0.6932 Val Accuracy: 50.00%Test Accuracy: 50.00%
# [26.51 min] Epoch 177/200 Train Loss: 0.6932 Val Loss: 0.6932 Val Accuracy: 50.00%Test Accuracy: 50.00%
# [26.66 min] Epoch 178/200 Train Loss: 0.6932 Val Loss: 0.6932 Val Accuracy: 50.00%Test Accuracy: 50.00%
# [26.81 min] Epoch 179/200 Train Loss: 0.6932 Val Loss: 0.6932 Val Accuracy: 50.00%Test Accuracy: 50.00%
# [26.96 min] Epoch 180/200 Train Loss: 0.6932 Val Loss: 0.6932 Val Accuracy: 50.00%Test Accuracy: 50.00%
# [27.11 min] Epoch 181/200 Train Loss: 0.6932 Val Loss: 0.6932 Val Accuracy: 50.00%Test Accuracy: 50.00%
# [27.26 min] Epoch 182/200 Train Loss: 0.6932 Val Loss: 0.6932 Val Accuracy: 50.00%Test Accuracy: 50.00%
# [27.41 min] Epoch 183/200 Train Loss: 0.6932 Val Loss: 0.6932 Val Accuracy: 50.00%Test Accuracy: 50.00%
# [27.55 min] Epoch 184/200 Train Loss: 0.6932 Val Loss: 0.6932 Val Accuracy: 50.00%Test Accuracy: 50.00%
# [27.70 min] Epoch 185/200 Train Loss: 0.6924 Val Loss: 0.6937 Val Accuracy: 49.05%Test Accuracy: 50.15%
# [27.85 min] Epoch 186/200 Train Loss: 0.6927 Val Loss: 0.6932 Val Accuracy: 50.00%Test Accuracy: 49.85%
# [28.00 min] Epoch 187/200 Train Loss: 0.6933 Val Loss: 0.6932 Val Accuracy: 50.00%Test Accuracy: 49.85%
# [28.15 min] Epoch 188/200 Train Loss: 0.6932 Val Loss: 0.6932 Val Accuracy: 50.00%Test Accuracy: 49.85%
# [28.30 min] Epoch 189/200 Train Loss: 0.6933 Val Loss: 0.6932 Val Accuracy: 50.00%Test Accuracy: 49.85%
# [28.45 min] Epoch 190/200 Train Loss: 0.6932 Val Loss: 0.6932 Val Accuracy: 50.00%Test Accuracy: 49.85%
# [28.60 min] Epoch 191/200 Train Loss: 0.6932 Val Loss: 0.6932 Val Accuracy: 50.00%Test Accuracy: 49.85%
# [28.74 min] Epoch 192/200 Train Loss: 0.6932 Val Loss: 0.6932 Val Accuracy: 50.00%Test Accuracy: 49.85%
# [28.89 min] Epoch 193/200 Train Loss: 0.6934 Val Loss: 0.6932 Val Accuracy: 50.00%Test Accuracy: 49.85%
# [29.04 min] Epoch 194/200 Train Loss: 0.6932 Val Loss: 0.6932 Val Accuracy: 50.00%Test Accuracy: 49.85%
# [29.18 min] Epoch 195/200 Train Loss: 0.6932 Val Loss: 0.6925 Val Accuracy: 53.80%Test Accuracy: 51.00%
# [29.33 min] Epoch 196/200 Train Loss: 0.6929 Val Loss: 0.6932 Val Accuracy: 50.00%Test Accuracy: 49.85%
# [29.48 min] Epoch 197/200 Train Loss: 0.6933 Val Loss: 0.6932 Val Accuracy: 50.00%Test Accuracy: 49.85%
# [29.62 min] Epoch 198/200 Train Loss: 0.6931 Val Loss: 0.6932 Val Accuracy: 50.00%Test Accuracy: 49.85%
# [29.77 min] Epoch 199/200 Train Loss: 0.6932 Val Loss: 0.6932 Val Accuracy: 50.00%Test Accuracy: 49.85%
# [29.92 min] Epoch 200/200 Train Loss: 0.6932 Val Loss: 0.6932 Val Accuracy: 50.00%Test Accuracy: 49.85%

# %%
torch.save(model.state_dict(), os.path.join(cwd, 'samll_model.pth'))

# %%
# Plot accuracies
plt.figure(figsize=(10, 5))
plt.plot(train_accuracies, label="Train Accuracy")
plt.plot(val_accuracies, label="Validation Accuracy")
plt.plot(test_accuracies, label="Test Accuracy")
plt.ylim(0, 100)  # Limit y-axis from 0 to 100
plt.xlabel("Epochs")
plt.ylabel("Accuracy (%)")
plt.title("Accuracies Over Epochs")
plt.legend()
plt.grid()
plt.savefig("accuracy_plot.png")
plt.show()

# Plot losses
plt.figure(figsize=(10, 5))
plt.plot(train_losses, label="Train Loss")
plt.plot(val_losses, label="Validation Loss")
plt.plot(test_losses, label="Test Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Losses Over Epochs")
plt.legend()
plt.grid()
plt.savefig("loss_plot.png")
plt.show()
